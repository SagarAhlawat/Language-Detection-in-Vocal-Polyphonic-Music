# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd drive/MyDrive/Wave-U-Net-Pytorch-master/
# Out:
# /content/drive/MyDrive/Wave-U-Net-Pytorch-master

# %%
pip install git+https://github.com/nficano/pytube
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/nficano/pytube to /tmp/pip-req-build-anknanib
#   Running command git clone -q https://github.com/nficano/pytube /tmp/pip-req-build-anknanib
# ...
#   Created wheel for pytube: filename=pytube-12.1.0-py3-none-any.whl size=56522 sha256=6a35e2cdd77a4ff81596df321549c47b8e6c6e5f3fedca0dd6e164d017ce6a20
#   Stored in directory: /tmp/pip-ephem-wheel-cache-l0ewn7th/wheels/68/f0/02/319083d0126c7e7fb3ac6a803bbff62f852cfd07b9371e05e4
# Successfully built pytube
# ...

# %%
# !pip3 install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 753.4 MB 7.2 kB/s
# ...
#      |████████████████████████████████| 4.0 MB 54.1 MB/s
# ...
#      |████████████████████████████████| 963 kB 25.5 MB/s
# ...
#      |████████████████████████████████| 130 kB 59.1 MB/s
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1+cu113
#     Uninstalling torch-1.12.1+cu113:
#       Successfully uninstalled torch-1.12.1+cu113
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.13.1+cu113
#     Uninstalling torchvision-0.13.1+cu113:
#       Successfully uninstalled torchvision-0.13.1+cu113
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.13.1 requires torch==1.12.1, but you have torch 1.4.0 which is incompatible.
# ...

# %%
from pytube import Playlist
from pytube import YouTube
import xlwt

# %%
my_xls=xlwt.Workbook(encoding='UTF-8')
my_sheet=my_xls.add_sheet("songs1")
# my_sheet.write(0,0,"URL")
p = Playlist('https://www.youtube.com/playlist?list=PLXLGtVWUBc2fMbrMvUBSfrF_MkvxCZdbN')
#https://www.youtube.com/playlist?list=RDCLAK5uy_kCO40RkB9MzrBJF8p6uDcMP7tq2SUmrOE HINDI
#https://www.youtube.com/playlist?list=PLRaBkk3DzHnPCNHp0eeeX5LwOWAOCdhR5 bengali
#https://www.youtube.com/playlist?list=RDCLAK5uy_lyVnWI5JnuwKJiuE-n1x-Un0mj9WlEyZw telugu
#https://www.youtube.com/playlist?list=PLZqSTpnMDm493pzF3rf2LVsjYU38t4DlH malyalam
import os

# %%
# my_sheet.write(0,1,"Name")
# !pip3 uninstall pytube
# Out:
# Found existing installation: pytube 12.1.0
# Uninstalling pytube-12.1.0:
#   Would remove:
#     /usr/local/bin/pytube
#     /usr/local/lib/python3.7/dist-packages/pytube-12.1.0.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/pytube/*
# Proceed (y/n)? y
#   Successfully uninstalled pytube-12.1.0

# %%
# !pip3 uninstall pytube3
# Out:
# Found existing installation: pytube3 9.6.4
# Uninstalling pytube3-9.6.4:
#   Would remove:
#     /usr/local/bin/pytube3
#     /usr/local/lib/python3.7/dist-packages/pytube3-9.6.4.dist-info/*
# Proceed (y/n)? y
#   Successfully uninstalled pytube3-9.6.4

# %%
j = 0
i = 0
new_file = ''
for v in p.video_urls:
  try:
    
    
    my_sheet.write(i,0,v)
    yt=YouTube(v)

    video = yt.streams.filter(only_audio=True).first()
    out_file = video.download(output_path=".")
    base, ext = os.path.splitext(out_file)
    new_file = base + '.wav'
    x = new_file.split("/")
    os.rename(out_file, new_file)
    my_sheet.write(i,1,x[-1])
    i+=1
  except:
    print('error occured')
  # !python predict.py --load_model checkpoints/waveunet/model --input new_file --cuda
  # os.remove(new_file)
my_xls.save("results.xlsx")

# %%
# new_file = "./Main Agar Kahoon  Om Shanti Om[2008].wav"

# %%
# !python predict.py --load_model checkpoints/waveunet/model --cuda ##--instruments "vocals"
# Out:
# Nee  Varathan  Video Song  Fahadh Faasil  Amal Neerad  Nazriya Nazim  ANP & FFF.wav
# Using valid convolutions with 97961 inputs and 88409 outputs
# move model to gpu
# Loading model from checkpoint checkpoints/waveunet/model
# Step 132065
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Abrahaminte Santhathikal Video Song  Mulla Poovithalo  Serin Francis  Haricharan  Shaji Padoor.wav
# Using valid convolutions with 97961 inputs and 88409 outputs
# move model to gpu
# Loading model from checkpoint checkpoints/waveunet/model
# Step 132065
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Theevandi  Jeevamshamayi  Video Song  August Cinema  Kailas Menon  Shreya Ghoshal  Harisankar.wav
# ...

# %%
import xlrd
workbook = xlrd.open_workbook("results.xlsx","rb")
sheets = workbook.sheet_names()
required_data = []
sh = workbook.sheet_by_name("songs1")
for rownum in range(sh.nrows):
  row_valaues = sh.row_values(rownum)

  #print(row_valaues[1])
  if os.path.exists(row_valaues[1]):
    os.remove(row_valaues[1])
    print(row_valaues[1])
  nef = row_valaues[1] + '_bass.wav'
  nef2 = row_valaues[1] + '_drums.wav'
  nef3 = row_valaues[1] + '_other.wav'
  if os.path.exists(nef):
    os.remove(nef)
  if os.path.exists(nef2):
    os.remove(nef2)
  if os.path.exists(nef3):
    os.remove(nef3)
# Out:
# Nee  Varathan  Video Song  Fahadh Faasil  Amal Neerad  Nazriya Nazim  ANP & FFF.wav
# Abrahaminte Santhathikal Video Song  Mulla Poovithalo  Serin Francis  Haricharan  Shaji Padoor.wav
# Theevandi  Jeevamshamayi  Video Song  August Cinema  Kailas Menon  Shreya Ghoshal  Harisankar.wav
# Kerala Varma Pazhassi Raja - Kunnathae Video  Ilaiyaraaja.wav
# Mandhaara Full Video Song 4K  Bhaagamathie Malayalam Movie Songs  Anushka Shetty  Unni Mukundan.wav
# A DANCE TRIBUTE TO MALAYALAM CINEMA.wav
# Kinavu Kondoru Video Song  Sudani From Nigeria  Rex Vijayan  Imam Majboor  Soubin Shahir.wav
# Kandittum Kandittum Full Video Song  Villain  Mohanlal  Manju Warrier  Raashi  Vishal  Yesudas.wav
# Aadu 2 Official 4K Video Song  Changaathi Nannaayaal  Jayasurya  Shaan Rahman.wav
# Payye Veeshum Kaatil Video Song 4K  Aanandam  Vineeth Sreenivasan  Ganesh Raj.wav
# new malayalam album song.wav
# Kera nirakalaadum - Jalolsavam malayalam movie video song.wav
# ...

# %%
pip install --upgrade tbb

# %%
# !python predict1 --load_model checkpoints/waveunet/model --input "audio_examples/tl1/3.wav" --cuda
# Out:
# /usr/local/lib/python3.7/dist-packages/resampy/interpn.py:114: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   _resample_loop_p(x, t_out, interp_win, interp_delta, num_table, scale, y)
# Using valid convolutions with 97961 inputs and 88409 outputs
# move model to gpu
# Loading model from checkpoint checkpoints/waveunet/model
# Step 132065
